# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
from datetime import datetime

# API endpoint and parameters
WEATHER_ENDPOINT = "https://api.openweathermap.org/data/2.5/weather"
API_KEY = "2a3ce56db80071bc0a4f1ea622a99fed"  # Replace with your actual API key


provinces = {
    "Chiang Mai":{
        "lat": 14.0134,
        "lon": 98.6601
    },
    "Lamphun":{
        "lat": 18.5745,
        "lon": 99.0087
    },
    "Lampang":{
        "lat": 17.6289,
        "lon": 100.0977
    },
    "Uttaradit":{
        "lat": 17.6255,
        "lon": 100.0942
    },
    "Phrae":{
        "lat": 18.1459,
        "lon": 100.1410
    },
    "Nan":{
        "lat": 18.7838,
        "lon": 100.7789
    },
    "Phayao":{
        "lat": 19.1920,
        "lon": 99.8788
    },
    "Chiang Rai":{
        "lat": 19.9086 ,
        "lon": 99.8325
    },
    "Mae Hong Son":{
        "lat": 19.3006 ,
        "lon": 97.9686
    }
}
# Function to fetch and process weather data
def get_weather_data(province='Pathum Thani'):
    
    params = {
        "lat": provinces[province]['lat'],
        "lon": provinces[province]['lon'],
        "appid": API_KEY,
        "units": "metric"
    }
    try:
        # Make API request
        response = requests.get(WEATHER_ENDPOINT, params=params)
        response.raise_for_status()  # Raise an exception for bad status codes
        data = response.json()
        
        # Convert timestamp to datetime
        timestamp = datetime.fromtimestamp(data['dt'])
        
        # Create dictionary with required fields
        weather_dict = {
            'timestamp': timestamp,
            'year': timestamp.year,
            'month': timestamp.month,
            'day': timestamp.day,
            'hour': timestamp.hour,
            'minute': timestamp.minute,
            'requested_province':province,
            'location': data['name'],
            'weather_main': data['weather'][0]['main'],
            'weather_description': data['weather'][0]['description'],
            'main.temp': data['main']['temp']
        }
        
        # Create DataFrame
        # df = pd.DataFrame([weather_dict])
        
        # return df
        return weather_dict
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None
    except KeyError as e:
        print(f"Error processing data: Missing key {e}")
        return None

# %%
df=pd.DataFrame([get_weather_data(p) for p in list(provinces.keys())])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   timestamp            9 non-null      datetime64[ns]
#  1   year                 9 non-null      int64
#  2   month                9 non-null      int64
#  3   day                  9 non-null      int64
#  4   hour                 9 non-null      int64
#  5   minute               9 non-null      int64
#  6   requested_province   9 non-null      object
#  7   location             9 non-null      object
#  8   weather_main         9 non-null      object
#  9   weather_description  9 non-null      object
#  10  main.temp            9 non-null      float64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(4)
# memory usage: 920.0+ bytes
#             timestamp  year  month  day  hour  minute requested_province  \
# 0 2025-04-28 16:57:29  2025      4   28    16      57         Chiang Mai
# 1 2025-04-28 16:57:30  2025      4   28    16      57            Lamphun
# 2 2025-04-28 16:57:31  2025      4   28    16      57            Lampang
# 3 2025-04-28 16:57:32  2025      4   28    16      57          Uttaradit
# 4 2025-04-28 16:57:34  2025      4   28    16      57              Phrae
#
#          location weather_main weather_description  main.temp
# 0           Dawei         Rain          light rain      28.35
# 1         Lamphun       Clouds    scattered clouds      34.62
# 2  Ban Tha It Bon       Clouds    scattered clouds      35.54
# 3       Uttaradit       Clouds    scattered clouds      35.54
# 4           Phrae       Clouds          few clouds      33.36

# %%
import pandas as pd

# lakeFS credentials from your docker-compose.yml
ACCESS_KEY = "access_key"
SECRET_KEY = "secret_key"

# lakeFS endpoint (running locally)
#lakefs_endpoint = "http://lakefs-dev:8000/"
lakefs_endpoint = "http://localhost:8000/"


# lakeFS repository, branch, and file path
repo = "weather"
branch = "main"
path = "weather.parquet"

# Construct the full lakeFS S3-compatible path
lakefs_s3_path = f"s3a://{repo}/{branch}/{path}"

# Configure storage_options for lakeFS (S3-compatible)
storage_options = {
    "key": ACCESS_KEY,
    "secret": SECRET_KEY,
    "client_kwargs": {
        "endpoint_url": lakefs_endpoint
    }
}

# %%
pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyarrow in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (20.0.0)
#
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fsspec
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: fsspec in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (2025.3.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install s3fs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting s3fs
#   Downloading s3fs-2025.3.2-py3-none-any.whl.metadata (1.9 kB)
# Collecting aiobotocore<3.0.0,>=2.5.4 (from s3fs)
#   Downloading aiobotocore-2.21.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: fsspec==2025.3.2.* in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from s3fs) (2025.3.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from s3fs)
#   Downloading aiohttp-3.11.18-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting aioitertools<1.0.0,>=0.5.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading aioitertools-0.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting botocore<1.37.2,>=1.37.0 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading botocore-1.37.1-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Collecting jmespath<2.0.0,>=0.7.1 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting multidict<7.0.0,>=6.0.0 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading multidict-6.4.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting wrapt<2.0.0,>=1.10.10 (from aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading wrapt-1.17.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading frozenlist-1.6.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading propcache-0.3.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs)
#   Downloading yarl-1.20.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (72 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (4.12.2)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<1.37.2,>=1.37.0->aiobotocore<3.0.0,>=2.5.4->s3fs)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.15.0)
# Requirement already satisfied: idna>=2.0 in /Users/siripreyacharoenjit/Library/Python/3.9/lib/python/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.10)
# Downloading s3fs-2025.3.2-py3-none-any.whl (30 kB)
# Downloading aiobotocore-2.21.1-py3-none-any.whl (78 kB)
# Downloading aiohttp-3.11.18-cp39-cp39-macosx_11_0_arm64.whl (457 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aioitertools-0.12.0-py3-none-any.whl (24 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading botocore-1.37.1-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 1.0 MB/s eta 0:00:0000:010:00:03
# Downloading frozenlist-1.6.0-cp39-cp39-macosx_11_0_arm64.whl (122 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading multidict-6.4.3-cp39-cp39-macosx_11_0_arm64.whl (37 kB)
# Downloading propcache-0.3.1-cp39-cp39-macosx_11_0_arm64.whl (46 kB)
# Downloading wrapt-1.17.2-cp39-cp39-macosx_11_0_arm64.whl (38 kB)
# Downloading yarl-1.20.0-cp39-cp39-macosx_11_0_arm64.whl (95 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Installing collected packages: wrapt, urllib3, propcache, multidict, jmespath, frozenlist, async-timeout, aioitertools, aiohappyeyeballs, yarl, botocore, aiosignal, aiohttp, aiobotocore, s3fs
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
# Successfully installed aiobotocore-2.21.1 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aioitertools-0.12.0 aiosignal-1.3.2 async-timeout-5.0.1 botocore-1.37.1 frozenlist-1.6.0 jmespath-1.0.1 multidict-6.4.3 propcache-0.3.1 s3fs-2025.3.2 urllib3-1.26.20 wrapt-1.17.2 yarl-1.20.0
#
# [notice] A new release of pip is available: 24.2 -> 25.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df.to_parquet(
    lakefs_s3_path,
    storage_options=storage_options,
    partition_cols=['year','month','day','hour']
)

# %%
from datetime import datetime
import pytz

dt = datetime.now()
thai_tz = pytz.timezone('Asia/Bangkok')
dt = dt.replace(tzinfo=thai_tz)
